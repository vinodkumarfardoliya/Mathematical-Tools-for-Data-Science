# %% [markdown]
# ** * NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP. * **
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,'b')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_yticks([0, 50, 100, 150, 200])
ax.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig=plt.figure()
ax1= fig.add_axes([0,0,1,1])
ax2= fig.add_axes([0.2,0.5,0.2,0.2])
ax2.yaxis.set_ticks(np.arange(0,1.1,0.2))
ax2.xaxis.set_ticks(np.arange(0,1.1,0.2))
# Out:
# [<matplotlib.axis.XTick at 0x247f41570a0>,
#  <matplotlib.axis.XTick at 0x247f4157070>,
#  <matplotlib.axis.XTick at 0x247f4150760>,
#  <matplotlib.axis.XTick at 0x247f4191610>,
#  <matplotlib.axis.XTick at 0x247f4191d60>,
#  <matplotlib.axis.XTick at 0x247f4191a00>]

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig=plt.figure()
ax1= fig.add_axes([0,0,1,1])
ax2= fig.add_axes([0.2,0.5,0.2,0.2])
ax1.yaxis.set_ticks(np.arange(0,201,50))
ax2.yaxis.set_ticks(np.arange(0,201,50))
ax2.xaxis.set_ticks(np.arange(0,101,20))
ax1.plot(x,y,'brown')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax2.plot(x,y,'brown')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig=plt.figure()
ax1= fig.add_axes([0,0,1,1])
ax2= fig.add_axes([0.2,0.5,0.4,0.4])

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
fig=plt.figure()
ax1= fig.add_axes([0,0,1,1])
ax2= fig.add_axes([0.2,0.5,0.4,0.4])

ax1.plot(x,z,'b')
ax1.set_xlabel('X')
ax1.set_ylabel('Z')

ax2.plot(x,y,'b')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_xlim([20,22])
ax2.set_ylim([30,50])
ax2.set_title('zoom')
# Out:
# Text(0.5, 1.0, 'zoom')

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y,'b', lw=3, ls='--')
axes[1].plot(x,z,'r', lw=3)

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(13,2.5))
axes[0].plot(x,y,'b', lw=5)
axes[1].plot(x,z,'r', lw=3, ls='--')

# %% [markdown]
# # Great Job!
