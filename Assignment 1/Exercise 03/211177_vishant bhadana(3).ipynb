# %% [markdown]
# ___
# # Ecommerce Purchases Exercise
#
# In this Exercise you will be given some Fake Data about some purchases done through Amazon! Just go ahead and follow the directions and try your best to answer the questions and complete the tasks. Feel free to reference the solutions. Most of the tasks can be solved in different ways. For the most part, the questions get progressively harder.
#
# Please excuse anything that doesn't make "Real-World" sense in the dataframe, all the data is fake and made-up.
#
# Also note that all of these questions can be answered with one line of code.
# ____
# ** Import pandas and read in the Ecommerce Purchases csv file and set it to a DataFrame called ecom. **

# %%
import pandas as pd
ecom=pd.read_csv('Ecommerce Purchases')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 ecom=pd.read_csv('Ecommerce Purchases')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
import pandas as pd
ecom=pd.read_csv('Ecommerce Purchases')
ecom.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 ecom=pd.read_csv('Ecommerce Purchases')
#       3 ecom.head()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ** How many rows and columns are there? **

# %%
import pandas as pd
ecom=pd.read_csv('Ecommerce Purchases')
ecom.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 ecom=pd.read_csv('Ecommerce Purchases')
#       3 ecom.info()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ** What is the average Purchase Price? **

# %%
import pandas as pd
ecom=pd.read_csv('Ecommerce Purchases')
print(ecom[ecom['Purchase Price'].isnull()])
ecom['Purchase Price'] = pd.to_numeric(ecom['Purchase Price'], errors='coerce')
ecom = ecom.dropna(subset=['Purchase Price'])
#ecom['Purchase Price'] = ecom['Purchase Price'].astype('int64')
ecom['Purchase Price'].mean()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 ecom=pd.read_csv('Ecommerce Purchases')
#       3 print(ecom[ecom['Purchase Price'].isnull()])
#       4 ecom['Purchase Price'] = pd.to_numeric(ecom['Purchase Price'], errors='coerce')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ** What were the highest and lowest purchase prices? **

# %%
import pandas as pd
ecom=pd.read_csv('Ecommerce Purchases')
print(ecom[ecom['Purchase Price'].isnull()])
ecom['Purchase Price'] = pd.to_numeric(ecom['Purchase Price'], errors='coerce')
ecom = ecom.dropna(subset=['Purchase Price'])
#ecom['Purchase Price'] = ecom['Purchase Price'].astype('int64')
ecom['Purchase Price'].max()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [53], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 ecom=pd.read_csv('Ecommerce Purchases')
#       3 print(ecom[ecom['Purchase Price'].isnull()])
#       4 ecom['Purchase Price'] = pd.to_numeric(ecom['Purchase Price'], errors='coerce')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd
ecom=pd.read_csv('Ecommerce Purchases')
print(ecom[ecom['Purchase Price'].isnull()])
ecom['Purchase Price'] = pd.to_numeric(ecom['Purchase Price'], errors='coerce')
ecom = ecom.dropna(subset=['Purchase Price'])
#ecom['Purchase Price'] = ecom['Purchase Price'].astype('int64')
ecom['Purchase Price'].min()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [19], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 ecom=pd.read_csv('Ecommerce Purchases')
#       3 print(ecom[ecom['Purchase Price'].isnull()])
#       4 ecom['Purchase Price'] = pd.to_numeric(ecom['Purchase Price'], errors='coerce')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ** How many people have English 'en' as their Language of choice on the website? **

# %%
import pandas as pd
ecom=pd.read_csv('Ecommerce Purchases')
ecom[ecom['Language']=='en'].count()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [52], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 ecom=pd.read_csv('Ecommerce Purchases')
#       3 ecom[ecom['Language']=='en'].count()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ** How many people have the job title of "Lawyer" ? **

# %%
import pandas as pd
ecom=pd.read_csv('Ecommerce Purchases')
ecom[ecom['Job']=='Lawyer'].count()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 ecom=pd.read_csv('Ecommerce Purchases')
#       3 ecom[ecom['Job']=='Lawyer'].count()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ** How many people made the purchase during the AM and how many people made the purchase during PM ? **
#
# **(Hint: Check out [value_counts()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html) ) **

# %%
import pandas as pd
ecom=pd.read_csv('Ecommerce Purchases')
#ecom[ecom['AM or PM']=='PM'].count()
#ecom[ecom['AM or PM']=='AM'].count()
ecom['AM or PM'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [26], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 ecom=pd.read_csv('Ecommerce Purchases')
#       3 #ecom[ecom['AM or PM']=='PM'].count()
#       4 #ecom[ecom['AM or PM']=='AM'].count()
#       5 ecom['AM or PM'].value_counts()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ** What are the 5 most common Job Titles? **

# %%
import pandas as pd
ecom=pd.read_csv('Ecommerce Purchases')
ecom['Job'].value_counts().head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [49], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 ecom=pd.read_csv('Ecommerce Purchases')
#       3 ecom['Job'].value_counts().head(5)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ** Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction? **

# %%
import pandas as pd
ecom=pd.read_csv('Ecommerce Purchases')
ecom[ecom['Lot']=='90 WT']['Purchase Price']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 ecom=pd.read_csv('Ecommerce Purchases')
#       3 ecom[ecom['Lot']=='90 WT']['Purchase Price']
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ** What is the email of the person with the following Credit Card Number: 4926535242672853 **

# %%
import pandas as pd
ecom=pd.read_csv('Ecommerce Purchases')
ecom[ecom["Credit Card"] == 4926535242672853]['Email']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [32], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 ecom=pd.read_csv('Ecommerce Purchases')
#       3 ecom[ecom["Credit Card"] == 4926535242672853]['Email']
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ** How many people have American Express as their Credit Card Provider *and* made a purchase above $95 ?**

# %%
import pandas as pd 

ecom=pd.read_csv('Ecommerce Purchases')
ecom[(ecom['CC Provider']=='American Express') & (ecom['Purchase Price']>95)].count()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [46], in <cell line: 3>()
#       1 import pandas as pd
# ----> 3 ecom=pd.read_csv('Ecommerce Purchases')
#       4 ecom[(ecom['CC Provider']=='American Express') & (ecom['Purchase Price']>95)].count()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ** Hard: How many people have a credit card that expires in 2025? **

# %%
import pandas as pd
ecom=pd.read_csv('Ecommerce Purchases')
sum(ecom['CC Exp Date'].apply(lambda x: x[3:]) == '25')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [45], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 ecom=pd.read_csv('Ecommerce Purchases')
#       3 sum(ecom['CC Exp Date'].apply(lambda x: x[3:]) == '25')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ** Hard: What are the top 5 most popular email providers/hosts (e.g. gmail.com, yahoo.com, etc...) **

# %%
import pandas as pd
ecom=pd.read_csv('Ecommerce Purchases')
ecom['Email'].apply(lambda x: x.split('@')[1]).value_counts().head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [42], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 ecom=pd.read_csv('Ecommerce Purchases')
#       3 ecom['Email'].apply(lambda x: x.split('@')[1]).value_counts().head(5)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# # Great Job!
